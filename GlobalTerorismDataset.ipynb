# %% [markdown]
# ### __LETS GROW MORE__
# ### __TASK-3__
# ### __EXPLORATORY DATA ANALYSIS ON DATASET- TERRORISM__
# ### __NAME:- ANKUR DAS__

# %%
#Importing Libraries
import numpy as np
import matplotlib.pyplot as plt    
import pandas as pd             
import seaborn as sns       
# %matplotlib inline

# %%
#Reading Data from csv file
terr=pd.read_csv('C:/Users/USER/OneDrive/Desktop/LGM-Task-3/globalterrorismdb_0718dist.csv',low_memory=False)
terr.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
terr.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
terr.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","extended":"Extended","provstate":"State","country_txt":"Country",
    "region_txt":"Region","attacktype1_txt":"Attack Type","target1":"Target","nkill":"Killed","nwound":"Wounded","summary":"Summary","gname":"Group",
    "weaptype1_txt":"Weapon Type","motive":"Motive","latitude":"Latitude","longitude":"Longitude","city":"City",
    "eventid":"Event","resolution":"Resolution"},inplace=True)

# %%
terr=terr[["Year","Month","Day","Extended","State","Country","Region","City","Latitude","Longitude","Attack Type",
        "Target","Wounded","Killed","Summary","Group","Motive","Weapon Type"]]

# %%
terr.head(20)
# Out:
#     Year  Month  Day  Extended        State             Country  \
# 0   1970      7    2         0          NaN  Dominican Republic
# 1   1970      0    0         0      Federal              Mexico
# 2   1970      1    0         0       Tarlac         Philippines
# 3   1970      1    0         0       Attica              Greece
# 4   1970      1    0         0      Fukouka               Japan
# 5   1970      1    1         0     Illinois       United States
# 6   1970      1    2         0   Montevideo             Uruguay
# 7   1970      1    2         0   California       United States
# 8   1970      1    2         0    Wisconsin       United States
# 9   1970      1    3         0    Wisconsin       United States
# 10  1970      1    1         0    Wisconsin       United States
# 11  1970      1    6         0     Colorado       United States
# 12  1970      1    8         0        Lazio               Italy
# 13  1970      1    9         0     Michigan       United States
# ...

# %%
#Adding New Column named Casaulty
terr["Killed"]=terr["Killed"].fillna(0)
terr["Wounded"]=terr["Wounded"].fillna(0)
terr["Casualty"]=terr["Killed"]+terr["Wounded"]

# %%
terr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Extended     181691 non-null  int64
#  4   State        181270 non-null  object
#  5   Country      181691 non-null  object
#  6   Region       181691 non-null  object
#  7   City         181257 non-null  object
#  8   Latitude     177135 non-null  float64
#  9   Longitude    177134 non-null  float64
#  10  Attack Type  181691 non-null  object
#  11  Target       181055 non-null  object
#  12  Wounded      181691 non-null  float64
#  13  Killed       181691 non-null  float64
#  14  Summary      115562 non-null  object
#  15  Group        181691 non-null  object
#  16  Motive       50561 non-null   object
#  17  Weapon Type  181691 non-null  object
# ...

# %%
terr.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Extended            0
# State             421
# Country             0
# Region              0
# City              434
# Latitude         4556
# Longitude        4557
# Attack Type         0
# Target            636
# Wounded             0
# Killed              0
# Summary         66129
# Group               0
# Motive         131130
# Weapon Type         0
# Casualty            0
# dtype: int64

# %%
terr.describe()
# Out:
#                 Year          Month            Day       Extended  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644       0.045346
# std        13.259430       3.388303       8.814045       0.208063
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000       0.000000
# 50%      2009.000000       6.000000      15.000000       0.000000
# 75%      2014.000000       9.000000      23.000000       0.000000
# max      2017.000000      12.000000      31.000000       1.000000
#
#             Latitude     Longitude        Wounded         Killed  \
# count  177135.000000  1.771340e+05  181691.000000  181691.000000
# mean       23.498343 -4.586957e+02       2.883296       2.266860
# std        18.569242  2.047790e+05      34.309747      11.227057
# min       -53.154613 -8.618590e+07       0.000000       0.000000
# ...

# %% [markdown]
# #### __Countries with Most Number of Terrorist Attacks__

# %%
terrco=terr["Country"].value_counts().head(20)
print("Top 20 Countries with most number of Terrorist Attacks:- \n",terrco)
# Out:
# Top 20 Countries with most number of Terrorist Attacks:-
#  Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(18,9))
terrco.plot(kind="bar",color="Blue",fontsize=12,label="Attacks")
plt.xlabel("Country",fontsize=16)
plt.ylabel("Number of Attacks ->",fontsize=16)
plt.title("Top 20 Countries with most number of Terrorist Attacks",fontsize=15)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# #### __States/Provinces with Most Number of Terrorist Attacks__

# %%
terrst=terr["State"].value_counts().head(20)
print("Top 20 States/Provinces with most number of Terrorist Attacks:- \n",terrst)
# Out:
# Top 20 States/Provinces with most number of Terrorist Attacks:-
#  Baghdad                                7645
# Northern Ireland                       4498
# Unknown                                4290
# Balochistan                            3710
# Saladin                                3411
# Al Anbar                               3299
# Nineveh                                3241
# Sindh                                  3206
# Khyber Pakhtunkhwa                     3084
# Diyala                                 3041
# Lima                                   2615
# Jammu and Kashmir                      2454
# Federally Administered Tribal Areas    2392
# San Salvador                           1923
# Antioquia                              1891
# Punjab                                 1778
# Kirkuk                                 1669
# Santiago Metropolitan                  1639
# Banaadir                               1613
# West Bank                              1584
# ...

# %%
plt.figure(figsize=(18,9))
terrst.plot(kind="bar",color="DarkGreen",fontsize=12,label="Attacks")
plt.xlabel("State",fontsize=16)
plt.ylabel("Number of Attacks ->",fontsize=16)
plt.title("Top 20 States/Provinces with most number of Terrorist Attacks",fontsize=15)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# #### __Regions with Most Number of Terrorist Attacks__

# %%
terrre=terr["Region"].value_counts().head(20)
print("Top 20 Regions with most number of Terrorist Attacks:- \n",terrre)
# Out:
# Top 20 Regions with most number of Terrorist Attacks:-
#  Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(20,10))
terrre.plot(kind="bar",color='red',fontsize=12,label="Attacks")
plt.xlabel("Region",fontsize=16)
plt.ylabel("Number of Attacks ->",fontsize=16)
plt.title("Top 20 Regions with most number of Terrorist Attacks",fontsize=15)
plt.legend(loc="upper right")
plt.show()

# %%
terrreg=pd.crosstab(terr.Year,terr.Region)
terrreg.plot(kind="area",figsize=(20,10),stacked="False",alpha=0.5)
plt.xlabel("Year",fontsize=16)
plt.ylabel("Number of Attacks->",fontsize=16)
plt.title("Attacks on Regions",fontsize=15)
plt.show()

# %% [markdown]
# #### __Cities with Most Number of Terrorist Attacks__

# %%
terrci=terr["City"].value_counts().head(20)
print("Top 20 Cities with most number of Terrorist Attacks:- \n",terrci)
# Out:
# Top 20 Cities with most number of Terrorist Attacks:-
#  Unknown           9775
# Baghdad           7589
# Karachi           2652
# Lima              2359
# Mosul             2265
# Belfast           2171
# Santiago          1621
# Mogadishu         1581
# San Salvador      1558
# Istanbul          1048
# Athens            1019
# Bogota             984
# Kirkuk             925
# Beirut             918
# Medellin           848
# Benghazi           840
# Peshawar           819
# Quetta             803
# Guatemala City     755
# Baqubah            745
# Name: City, dtype: int64

# %%
plt.figure(figsize=(18,9))
terrci.plot(kind="bar",color="Green",fontsize=12,label="Attacks")
plt.xlabel("City",fontsize=16)
plt.ylabel("Number of Attacks ->",fontsize=16)
plt.title("Top 20 Cities with most number of Terrorist Attacks",fontsize=15)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# #### __States of India with Most Number of Terrorist Attacks__

# %%
terrsti=terr[terr["Country"]=="India"]["State"].value_counts().head(20)
print("Top 20 states of India with Most number of Terrorist Attacks:- \n",terrsti)
# Out:
# Top 20 states of India with Most number of Terrorist Attacks:-
#  Jammu and Kashmir    2454
# Assam                1151
# Manipur              1100
# Chhattisgarh          979
# Punjab                949
# Jharkhand             887
# Bihar                 688
# West Bengal           650
# Odisha                428
# Maharashtra           302
# Meghalaya             294
# Andhra Pradesh        251
# Orissa                221
# Delhi                 208
# Uttar Pradesh         201
# Tamil Nadu            164
# Unknown               157
# Tripura               117
# Nagaland              115
# Kerala                 98
# Name: State, dtype: int64

# %%
plt.figure(figsize=(18,9))
terrsti.plot(kind="bar",color="darkviolet",fontsize=12,label="Attacks")
plt.xlabel("States of India",fontsize=16)
plt.ylabel("Number of Attacks ->",fontsize=16)
plt.title("Top 20 States of India with most number of Terrorist Attacks",fontsize=15)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# #### __Years in which Most Number of Terrorist Attacks have occured__

# %%
terrye=terr["Year"].value_counts().head(20)
print("Years with most number of Terrorist Attacks:- \n",terrye)
# Out:
# Years with most number of Terrorist Attacks:-
#  2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# Name: Year, dtype: int64

# %%
plt.figure(figsize=(18,9))
terrye.plot(kind="bar",color="indianred",fontsize=12,label="Attacks")
plt.xlabel("Year",fontsize=16)
plt.ylabel("Number of Attacks ->",fontsize=16)
plt.title("Years with most number of Terrorist Attacks",fontsize=15)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# #### __Groups with Most Number of Terrorist Attacks__

# %%
terrgr=terr["Group"].value_counts().head(20)
print("Top 20 Groups which have committed most number of Terrorist Attacks:- \n",terrgr)
# Out:
# Top 20 Groups which have committed most number of Terrorist Attacks:-
#  Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Basque Fatherland and Freedom (ETA)                  2024
# Communist Party of India - Maoist (CPI-Maoist)       1878
# Maoists                                              1630
# Liberation Tigers of Tamil Eelam (LTTE)              1606
# ...

# %%
plt.figure(figsize=(18,9))
terrgr.plot(kind="bar",color="brown",fontsize=12,label="Attacks")
plt.xlabel("Groups",fontsize=16)
plt.ylabel("Number of Attacks ->",fontsize=16)
plt.title("Top 20 Groups with most number of Terrorist Attacks",fontsize=15)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## __Conclusions:-__
# #### __1.Most Number of Terrorist Attacks in a Country:- 24236 in Iraq__
# #### __2.Most Number of Terrorist Attacks in a State/Province of a Country:- 7645 in Baghdad of Iraq__
# #### __3.Most Number of Terrorist Attacks in a Region:- 50474 in Middle East & North Africa__
# #### __4.Most Number of Terrorist Attacks in a City:- 7589 in Baghdad__
# #### __5.Most Number of Terrorist Attacks in a State of India:- 2454 in Jammu & Kashmir__
# #### __6.Most Number of Terrorist Attacks in a Year:- 16903 in 2014__
# #### __7.Most Number of Terrorist Attacks committed by a Group:- 7478 by Taliban__
